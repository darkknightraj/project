# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("creditcard.csv")

# %%
pd.options.display.max_columns = None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
def countplot_data(data, feature):
    '''
        Method to compute countplot of given dataframe
        Parameters:
            data(pd.Dataframe): Input Dataframe
            feature(str): Feature in Dataframe
    '''
    plt.figure(figsize=(10,10))
    sns.countplot(x=feature, data=data)
    plt.show()

# %%
countplot_data(data, data.Class)

# %%
def pairplot_data_grid(data, feature1, feature2, target):
    '''
        Method to construct pairplot of the given feature wrt data
        Parameters:
            data(pd.DataFrame): Input Dataframe
            feature1(str): First Feature for Pair Plot
            feature2(str): Second Feature for Pair Plot
            target: Target or Label (y)
    '''

    sns.FacetGrid(data, hue=target, height=6).map(plt.scatter, feature1, feature2).add_legend()
    plt.show()

# %%
pairplot_data_grid(data, "Time", "Amount", "Class")

# %%
pairplot_data_grid(data, "Amount", "Time", "Class")

# %%
data_refine = data[["Time", "Amount", "Class"]]
sns.pairplot(data_refine, hue="Class", height=6)
plt.show()

# %%
sns.FacetGrid(data_refine, hue="Class", height=6).map(sns.distplot,"Time").add_legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'],axis=1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data.tail()
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 284802 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941 -0.689256
# 284803  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802  1.214756
# 284804 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119 -0.183699
# 284805 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886 -1.042082
# 284806  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513 -0.188093
#
#              V14       V15       V16       V17       V18       V19       V20  \
# ...

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
284807- 275663
# Out:
# 9144

# %%
data['Class'].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
#Store Feature Matrix In X And Response (Target) In Vector y
X = data.drop('Class',axis=1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # under_sampling

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal.shape
# Out:
# (275190, 30)

# %%
normal_sample=normal.sample(n=473)
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)
new_data['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.536844  0.715120  0.890477 -0.485663  0.780068 -0.819557  0.989351
# 1 -0.297105 -0.220965  2.374124 -1.083331 -1.589881 -0.267116 -0.414808
# 2  1.059350 -1.292817  1.148512 -0.212956 -1.811134 -0.048644 -1.126513
# 3  0.041717  0.895154  0.293817 -0.592113  0.452007 -1.101148  1.053337
# 4  2.073705  0.261234 -1.660112  0.411640  0.525027 -0.866398  0.281791
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.299704 -0.306739  0.118097  0.955490  0.578920 -0.288048  0.182115
# 1 -1.611470 -1.606113  2.454723 -0.089489 -1.892393 -0.362185 -1.001561
# 2  0.211529  0.289651  0.323040 -0.510714 -0.721689 -1.291263 -0.586846
# 3 -0.235284 -0.118808 -0.427407 -0.857233  0.393944  0.506678  0.013419
# 4 -0.318631  0.278673 -0.419565 -0.298683  0.905841  1.465939 -1.122521
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_data.tail()
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10       V11       V12       V13       V14  \
# 941  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123 -6.665177
# 942  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532 -5.210141
# 943  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950 -4.057162
# 944  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455 -6.416628
# 945 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428 -1.948883
#
# ...

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.9263157894736842

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
precision_score(y_test,y_pred1)
# Out:
# 0.9489795918367347

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9300000000000002

# %% [markdown]
# # Decision Tree Classifier#

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)

y_pred2 = dt.predict(X_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.9315789473684211

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9494949494949495

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9353233830845771

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)

y_pred3 = rf.predict(X_test)
accuracy_score(y_test,y_pred3)
# Out:
# 0.9210526315789473

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9484536082474226

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9246231155778893

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})

# %%
final_data2 = pd.DataFrame({'Models':['LR','DT','RF'],
              "PRECISION":[precision_score(y_test,y_pred1)*100,
                     precision_score(y_test,y_pred2)*100,
                     precision_score(y_test,y_pred3)*100
                    ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  92.631579
# 1     DT  93.157895
# 2     RF  92.105263

# %%
final_data2
# Out:
#   Models  PRECISION
# 0     LR  94.897959
# 1     DT  94.949495
# 2     RF  94.845361

# %%
final_data3= pd.DataFrame({'Models':['LR','DT','RF'],
              "F!_SCORE":[f1_score(y_test,y_pred1)*100,
                     f1_score(y_test,y_pred2)*100,
                     f1_score(y_test,y_pred3)*100
                    ]})

# %%
final_data3
# Out:
#   Models   F!_SCORE
# 0     LR  93.000000
# 1     DT  93.532338
# 2     RF  92.462312

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  92.631579
# 1     DT  93.157895
# 2     RF  92.105263

# %%
sns.barplot(x = final_data.Models, y = final_data.ACC)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # over_sampling

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # logistic_regression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9442748646389767

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9729410626149231

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9138956056942349

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9424944688191399

# %% [markdown]
# # Decision tree

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9982012427777173

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9973140233389594

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9990909586749813

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9982017002107099

# %%
dt=DecisionTreeClassifier()
dt.fit(X_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
#joblib.dump(dt,"credit_card_model")

# %%
model = joblib.load("credit_card_model")

# %%
pred = model.predict([[1.293749,0.512285,0.663928,0.777484,0.943563,0.350716,0.685738,0.049363,1.115829,0.713238,1.997024,0.571820,0.535289,0.024289,0.265916,1.045270,0.302301,1.666366,0.466320,0.084303,0.005091,0.094199,0.164949,0.211984,0.116288,0.482267,0.025720,0.013220,0.293258]])

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Normal Transcation

# %%
pred=model.predict([[1.234235046,3.019740421,-4.304596885,4.73279513,3.624200831,-1.357745663,1.713444988,-0.496358487,-1.28285782,-2.447469255,2.101343865,-4.609628391,1.464377625,-6.079337193,-0.339237373,2.581850954,6.739384385,3.042493178,-2.721853122,0.009060836,-0.379068307,-0.704181032,-0.656804756,-1.632652957,1.488901448,0.566797273,-0.010016223,0.146792735,1000]])

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Fraudulent Transcation

# %% [markdown]
# # Random_forest_classifier

# %%
rf1 = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9999273229405138

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998545745396376

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999272819822931

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.459283
# 1     DT  99.813765
# 2     RF  99.992732

# %%
sns.barplot(x = final_data.Models, y = final_data.ACC)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # save the model

# %%
rf1 = RandomForestClassifier()
rf1.fit(X_res,y_res)

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_model1")
# Out:
# ['credit_card_model1']

# %%
model = joblib.load("credit_card_model1")

# %%
pred = model.predict([[1.293749,0.512285,0.663928,0.777484,0.943563,0.350716,0.685738,0.049363,1.115829,0.713238,1.997024,0.571820,0.535289,0.024289,0.265916,1.045270,0.302301,1.666366,0.466320,0.084303,0.005091,0.094199,0.164949,0.211984,0.116288,0.482267,0.025720,0.013220,0.293258]])

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Normal Transcation

# %%
pred=model.predict([[1.234235046,3.019740421,-4.304596885,4.73279513,3.624200831,-1.357745663,1.713444988,-0.496358487,-1.28285782,-2.447469255,2.101343865,-4.609628391,1.464377625,-6.079337193,-0.339237373,2.581850954,6.739384385,3.042493178,-2.721853122,0.009060836,-0.379068307,-0.704181032,-0.656804756,-1.632652957,1.488901448,0.566797273,-0.010016223,0.146792735,1000]])

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Fraudulent Transcation
